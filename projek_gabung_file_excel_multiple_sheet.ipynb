# %% [markdown]
# <a href="https://colab.research.google.com/github/Rikipratama/Rikipratama/blob/main/projek_gabung_file_excel_multiple_sheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas numpy openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import openpyxl
from openpyxl.utils import get_column_letter

def check_merged_cells(workbook, sheet_name):
    """Memeriksa dan menghapus baris yang berisi sel yang di-merge"""
    worksheet = workbook[sheet_name]
    merged_ranges = worksheet.merged_cells.ranges
    rows_to_remove = set()

    for merged_range in merged_ranges:
        # Mendapatkan baris yang terlibat dalam merge
        start_row = merged_range.min_row
        end_row = merged_range.max_row
        for row in range(start_row, end_row + 1):
            rows_to_remove.add(row)

    # Mengurutkan baris yang akan dihapus secara terbalik untuk menghindari masalah indeks
    return sorted(rows_to_remove, reverse=True)

def process_excel_file(input_file, output_file, exclude_sheets=None):
    """
    Memproses file Excel dengan menggabungkan multiple sheet menjadi satu
    dengan pengecualian sheet yang ditentukan.
    """
    if exclude_sheets is None:
        exclude_sheets = []

    # Membaca workbook dengan openpyxl untuk memeriksa merged cells
    workbook = openpyxl.load_workbook(input_file)

    # Menyiapkan list untuk menyimpan semua data yang sudah diproses
    all_data = []

    # Statistik status
    total_sheets = len(workbook.sheetnames)
    processed_sheets = 0
    skipped_sheets = 0
    skipped_sheets_list = []
    empty_sheets = 0
    empty_sheets_list = []
    excluded_sheets = 0

    # Memproses setiap sheet
    for sheet_name in workbook.sheetnames:
        if sheet_name in exclude_sheets:
            print(f"Sheet '{sheet_name}' dilewati sesuai permintaan.")
            excluded_sheets += 1
            continue

        print(f"Memproses sheet: {sheet_name}")

        # Cek apakah sheet kosong
        worksheet = workbook[sheet_name]
        if worksheet.max_row <= 1:  # Hanya memiliki header atau kosong
            print(f"Sheet '{sheet_name}' kosong. Dilewati.")
            empty_sheets += 1
            empty_sheets_list.append(sheet_name)
            continue

        # Membaca data dengan pandas menggunakan engine openpyxl
        try:
            df = pd.read_excel(input_file, sheet_name=sheet_name, engine='openpyxl')

            # Cek apakah dataframe kosong
            if df.empty:
                print(f"Sheet '{sheet_name}' kosong. Dilewati.")
                empty_sheets += 1
                empty_sheets_list.append(sheet_name)
                continue

            # Jika tidak ada kolom yang diperlukan, lanjut ke sheet berikutnya
            required_columns = ['PLU', 'BARCODE', 'Nama Barang', 'Satuan']
            if not all(col in df.columns for col in required_columns):
                print(f"Sheet '{sheet_name}' tidak memiliki semua kolom yang diperlukan. Dilewati.")
                skipped_sheets += 1
                skipped_sheets_list.append(sheet_name)
                continue
        except Exception as e:
            print(f"Error saat membaca sheet '{sheet_name}': {e}. Dilewati.")
            skipped_sheets += 1
            skipped_sheets_list.append(sheet_name)
            continue

        # Memeriksa merged cells dan mendapatkan baris yang harus dihapus
        rows_to_remove = check_merged_cells(workbook, sheet_name)

        # Menghapus baris yang memiliki merged cells
        if rows_to_remove:
            # Menyesuaikan indeks baris (pandas dimulai dari 0, openpyxl dari 1)
            rows_to_remove_adjusted = [r-1 for r in rows_to_remove]
            print(f"Menghapus {len(rows_to_remove)} baris dengan merged cells dari sheet '{sheet_name}'")
            df = df.drop(rows_to_remove_adjusted, errors='ignore')
            df = df.reset_index(drop=True)

        # Menambahkan kolom informasi sumber sheet
        df['SumberSheet'] = sheet_name

        # Pastikan PLU dan BARCODE adalah tipe data text
        df['PLU'] = df['PLU'].astype(str)
        df['BARCODE'] = df['BARCODE'].astype(str)

        # Pastikan Satuan adalah bilangan bulat
        try:
            df['Satuan'] = pd.to_numeric(df['Satuan'], errors='coerce').fillna(0).astype(int)
        except Exception as e:
            print(f"Error mengkonversi kolom Satuan ke integer di sheet '{sheet_name}': {e}")
            # Jika konversi gagal, tetap pertahankan kolom asli

        # Mengisi nilai yang kosong dengan "No Data"
        df = df.fillna("No Data")

        # Menyimpan data yang sudah diproses
        all_data.append(df)
        processed_sheets += 1

    # Menggabungkan semua data jika ada
    if all_data:
        combined_df = pd.concat(all_data, ignore_index=True)

        # Pastikan hanya kolom yang diinginkan yang disimpan dengan urutan yang benar
        desired_columns = ['PLU', 'BARCODE', 'Nama Barang', 'Satuan', 'SumberSheet']
        combined_df = combined_df[desired_columns]

        # Menyimpan hasil ke file baru dengan engine openpyxl
        combined_df.to_excel(output_file, index=False, sheet_name='GabunganData', engine='openpyxl')
        print(f"\nFile berhasil disimpan: {output_file}")

        # Informasi status data
        print("\n===== LAPORAN STATUS PENGGABUNGAN =====")
        print(f"Total sheet dalam file: {total_sheets}")
        print(f"Sheet yang berhasil diproses: {processed_sheets}")
        print(f"Sheet yang dilewati karena dikecualikan: {excluded_sheets}")
        print(f"Sheet yang dilewati karena kosong: {empty_sheets}")
        if empty_sheets > 0:
            print(f"  List sheet kosong: {', '.join(empty_sheets_list)}")
        print(f"Sheet yang dilewati karena format tidak sesuai: {skipped_sheets}")
        if skipped_sheets > 0:
            print(f"  List sheet tidak sesuai: {', '.join(skipped_sheets_list)}")

        print("\n===== STATISTIK DATA HASIL GABUNGAN =====")
        print(f"Total baris data: {len(combined_df)}")
        for col in desired_columns:
            null_count = combined_df[col].isin(["No Data"]).sum()
            print(f"Kolom '{col}': {null_count} data kosong")

        # Statistik per sheet
        print("\n===== STATISTIK PER SHEET =====")
        sheet_stats = combined_df.groupby('SumberSheet').size()
        for sheet_name, count in sheet_stats.items():
            print(f"{sheet_name}: {count} baris")
    else:
        print("\n===== LAPORAN STATUS PENGGABUNGAN =====")
        print(f"Total sheet dalam file: {total_sheets}")
        print(f"Sheet yang berhasil diproses: {processed_sheets}")
        print(f"Sheet yang dilewati karena dikecualikan: {excluded_sheets}")
        print(f"Sheet yang dilewati karena kosong: {empty_sheets}")
        if empty_sheets > 0:
            print(f"  List sheet kosong: {', '.join(empty_sheets_list)}")
        print(f"Sheet yang dilewati karena format tidak sesuai: {skipped_sheets}")
        if skipped_sheets > 0:
            print(f"  List sheet tidak sesuai: {', '.join(skipped_sheets_list)}")
        print("\nTidak ada data yang diproses. Pastikan file Excel memiliki sheet dengan format yang sesuai.")

if __name__ == "__main__":
    # Contoh penggunaan:
    input_file = input("Masukkan path file Excel yang akan diproses: ")
    output_file = input("Masukkan path file output: ")

    # Pastikan file output memiliki ekstensi .xlsx
    if not output_file.lower().endswith('.xlsx'):
        output_file += '.xlsx'

    # Tanyakan sheet yang akan dikecualikan
    exclude_input = input("Masukkan nama sheet yang tidak ingin digabungkan (pisahkan dengan koma jika lebih dari satu): ")
    exclude_sheets = [s.strip() for s in exclude_input.split(',')] if exclude_input else []

    try:
        # Proses file
        process_excel_file(input_file, output_file, exclude_sheets)
    except Exception as e:
        print(f"Terjadi error: {e}")
        print("Pastikan file yang diinput ada dan memiliki format Excel (.xls atau .xlsx)")
# Out:
# Masukkan path file Excel yang akan diproses: /content/SO 11 MARET 2025 FIXX (2) - Copy.xlsx
# Masukkan path file output: gabungan data SO Team Pak Adri
# Masukkan nama sheet yang tidak ingin digabungkan (pisahkan dengan koma jika lebih dari satu): MASTER GT, Sheet1, MASTER
# Sheet 'MASTER GT' dilewati sesuai permintaan.
# Sheet 'Sheet1' dilewati sesuai permintaan.
# Sheet 'MASTER' dilewati sesuai permintaan.
# Memproses sheet: WALLS
# Memproses sheet: FLOOR MINUMAN
# Memproses sheet: RAK F5
# Memproses sheet: CAMPURAN
# Memproses sheet: RAK 001
# Memproses sheet: RAK 002
# Memproses sheet: RAK 003
# Menghapus 86 baris dengan merged cells dari sheet 'RAK 003'
# Memproses sheet: RAK 004
# Memproses sheet: RAK 005
# Memproses sheet: RAK 006
# Memproses sheet: RAK 007
# Memproses sheet: RAK 008
# Memproses sheet: RAK 009
# Memproses sheet: RAK 010
# Memproses sheet: RAK 011
# Memproses sheet: RAK 012
# Memproses sheet: RAK 013
# Memproses sheet: RAK 014
# Memproses sheet: RAK 015
# Memproses sheet: RAK 016
# Memproses sheet: RAK 17
# Memproses sheet: RAK 18
# Memproses sheet: RAK 19
# Memproses sheet: RAK 020
# Memproses sheet: RAK 021
# Memproses sheet: RAK 022
# Memproses sheet: RAK 023
# Memproses sheet: RAK 024
# Memproses sheet: RAK 025
# Memproses sheet: RAK 026
# Memproses sheet: RAK 027
# Memproses sheet: RAK 028
# Memproses sheet: RAK 029
# Memproses sheet: RAK 030
# Memproses sheet: RAK 031
# Memproses sheet: RAK 032
# Memproses sheet: RAK 033
# Memproses sheet: RAK 034
# Memproses sheet: RAK 035
# Memproses sheet: RAK 036
# Memproses sheet: RAK 037
# Memproses sheet: RAK 038
# Memproses sheet: RAK 039
# Memproses sheet: RAK 040
# Memproses sheet: RAK 41
# Memproses sheet: RAK 42
# Memproses sheet: RAK 43
# Memproses sheet: RAK 44
# Memproses sheet: RAK 45
# Memproses sheet: RAK 46
# Memproses sheet: RAK 47
# Memproses sheet: RAK 48
# Memproses sheet: RAK 49
# Memproses sheet: RAK 50
# Memproses sheet: RAK 51
# Memproses sheet: RAK 52
# Memproses sheet: RAK 53
# Memproses sheet: RAK 54
# Memproses sheet: RAK 55
# Memproses sheet: RAK 56
# Memproses sheet: RAK 57
# Sheet 'RAK 57' kosong. Dilewati.
# Memproses sheet: RAK 58
# Sheet 'RAK 58' kosong. Dilewati.
# Memproses sheet: RAK 59
# Memproses sheet: RAK 60
# Sheet 'RAK 60' kosong. Dilewati.
# Memproses sheet: RAK 61
# Memproses sheet: RAK 62
# Memproses sheet: RAK 63
# Memproses sheet: RAK 64
# Memproses sheet: RAK 65
# Memproses sheet: RAK 66
# Memproses sheet: RAK 67
# Memproses sheet: RAK 68
# Memproses sheet: RAK 69
# Memproses sheet: RAK 70
# Sheet 'RAK 70' kosong. Dilewati.
# Memproses sheet: RAK 71
# Sheet 'RAK 71' kosong. Dilewati.
# Memproses sheet: RAK 72
# Memproses sheet: RAK 73
# Memproses sheet: RAK 74
# Memproses sheet: RAK 75
# Memproses sheet: RAK 76
# Sheet 'RAK 76' tidak memiliki semua kolom yang diperlukan. Dilewati.
# Memproses sheet: RAK 77
# Sheet 'RAK 77' kosong. Dilewati.
# Memproses sheet: RAK 78
# Sheet 'RAK 78' kosong. Dilewati.
# Memproses sheet: RAK 79
# Memproses sheet: RAK 80
# Memproses sheet: RAK 81
# Memproses sheet: RAK 82
# Sheet 'RAK 82' kosong. Dilewati.
# Memproses sheet: RAK 83
# Sheet 'RAK 83' kosong. Dilewati.
# Memproses sheet: RAK 84
# Sheet 'RAK 84' kosong. Dilewati.
# Memproses sheet: RAK 85
# Sheet 'RAK 85' kosong. Dilewati.
# Memproses sheet: RAK 86
# Sheet 'RAK 86' kosong. Dilewati.
# Memproses sheet: RAK 87
# Sheet 'RAK 87' kosong. Dilewati.
# Memproses sheet: RAK 88
# Memproses sheet: RAK 89
# Sheet 'RAK 89' tidak memiliki semua kolom yang diperlukan. Dilewati.
# Memproses sheet: RAK 90
# Sheet 'RAK 90' tidak memiliki semua kolom yang diperlukan. Dilewati.
# Memproses sheet: RAK 91
# Memproses sheet: RAK 92
# Memproses sheet: RAK 93
# Memproses sheet: RAK 94
# Sheet 'RAK 94' kosong. Dilewati.
# Memproses sheet: RAK 95
# Memproses sheet: RAK 96
# Memproses sheet: RAK 97
# Sheet 'RAK 97' kosong. Dilewati.
# Memproses sheet: RAK 98
# Memproses sheet: RAK 99
# Memproses sheet: RAK 100
# Memproses sheet: RAK 101
# Memproses sheet: RAK 102
# Memproses sheet: RAK 103
# Memproses sheet: RAK 104
# Memproses sheet: RAK 105
# Memproses sheet: RAK 106
# Memproses sheet: RAK 107
# Menghapus 1 baris dengan merged cells dari sheet 'RAK 107'
# Memproses sheet: RAK 108
# Memproses sheet: RAK 109
# Memproses sheet: RAK 110
# Memproses sheet: RAK 111
# Sheet 'RAK 111' kosong. Dilewati.
# Memproses sheet: RAK 112
# Menghapus 67 baris dengan merged cells dari sheet 'RAK 112'
#
# File berhasil disimpan: gabungan data SO Team Pak Adri.xlsx
#
# ===== LAPORAN STATUS PENGGABUNGAN =====
# Total sheet dalam file: 119
# Sheet yang berhasil diproses: 97
# Sheet yang dilewati karena dikecualikan: 3
# Sheet yang dilewati karena kosong: 16
#   List sheet kosong: RAK 57, RAK 58, RAK 60, RAK 70, RAK 71, RAK 77, RAK 78, RAK 82, RAK 83, RAK 84, RAK 85, RAK 86, RAK 87, RAK 94, RAK 97, RAK 111
# Sheet yang dilewati karena format tidak sesuai: 3
#   List sheet tidak sesuai: RAK 76, RAK 89, RAK 90
#
# ===== STATISTIK DATA HASIL GABUNGAN =====
# Total baris data: 3971
# Kolom 'PLU': 0 data kosong
# Kolom 'BARCODE': 0 data kosong
# Kolom 'Nama Barang': 1205 data kosong
# Kolom 'Satuan': 0 data kosong
# Kolom 'SumberSheet': 0 data kosong
#
# ===== STATISTIK PER SHEET =====
# CAMPURAN: 65 baris
# FLOOR MINUMAN: 3 baris
# RAK 001: 69 baris
# RAK 002: 73 baris
# RAK 003: 31 baris
# RAK 004: 141 baris
# RAK 005: 116 baris
# RAK 006: 80 baris
# RAK 007: 95 baris
# RAK 008: 123 baris
# RAK 009: 100 baris
# RAK 010: 59 baris
# RAK 011: 45 baris
# RAK 012: 63 baris
# RAK 013: 57 baris
# RAK 014: 68 baris
# RAK 015: 71 baris
# RAK 016: 66 baris
# RAK 020: 74 baris
# RAK 021: 25 baris
# RAK 022: 20 baris
# RAK 023: 38 baris
# RAK 024: 56 baris
# RAK 025: 17 baris
# RAK 026: 52 baris
# RAK 027: 56 baris
# RAK 028: 51 baris
# RAK 029: 14 baris
# RAK 030: 49 baris
# RAK 031: 53 baris
# RAK 032: 62 baris
# RAK 033: 56 baris
# RAK 034: 20 baris
# RAK 035: 23 baris
# RAK 036: 35 baris
# RAK 037: 36 baris
# RAK 038: 42 baris
# RAK 039: 36 baris
# RAK 040: 56 baris
# RAK 100: 27 baris
# RAK 101: 18 baris
# RAK 102: 29 baris
# RAK 103: 16 baris
# RAK 104: 19 baris
# RAK 105: 26 baris
# RAK 106: 77 baris
# RAK 107: 40 baris
# RAK 108: 80 baris
# RAK 109: 81 baris
# RAK 110: 109 baris
# RAK 112: 1 baris
# RAK 17: 14 baris
# RAK 18: 37 baris
# RAK 19: 33 baris
# RAK 41: 44 baris
# RAK 42: 45 baris
# RAK 43: 103 baris
# RAK 44: 63 baris
# RAK 45: 17 baris
# RAK 46: 21 baris
# RAK 47: 45 baris
# RAK 48: 26 baris
# RAK 49: 20 baris
# RAK 50: 23 baris
# RAK 51: 23 baris
# RAK 52: 5 baris
# RAK 53: 11 baris
# RAK 54: 6 baris
# RAK 55: 11 baris
# RAK 56: 8 baris
# RAK 59: 27 baris
# RAK 61: 34 baris
# RAK 62: 17 baris
# RAK 63: 19 baris
# RAK 64: 15 baris
# RAK 65: 29 baris
# RAK 66: 9 baris
# RAK 67: 24 baris
# RAK 68: 22 baris
# RAK 69: 16 baris
# RAK 72: 18 baris
# RAK 73: 21 baris
# RAK 74: 26 baris
# RAK 75: 81 baris
# RAK 79: 7 baris
# RAK 80: 18 baris
# RAK 81: 48 baris
# RAK 88: 33 baris
# RAK 91: 26 baris
# RAK 92: 31 baris
# RAK 93: 7 baris
# RAK 95: 14 baris
# RAK 96: 16 baris
# RAK 98: 32 baris
# RAK 99: 65 baris
# RAK F5: 13 baris
# WALLS: 29 baris
